# %% [markdown]
# README:
# - updated: reorganize codes based on v5
# - use vectorized method for multi-class classification

# %%
import pandas as pd
import os
os.chdir('/Users/liyuan/desktop/CSAir/codes')
import numpy as np
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

from sklearn.naive_bayes import MultinomialNB  
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from modeling_main import ReviewClassify
from tokenization import Tokenization
from help import get_tokenized_sent, get_stopwords

from prepare_data import PrepareData
from modeling import Modeling

import keras
from keras.utils import to_categorical
from sklearn.multiclass import OneVsRestClassifier
import seaborn as sns
from sklearn.metrics import confusion_matrix
from pandas_ml import ConfusionMatrix
# Out:
# Using TensorFlow backend.

# %%
def predict_label(model,X_train,y_train):
    ''' predict label for each review, by picking the class with highest probability'''
    multi_class_clf = OneVsRestClassifier(model, n_jobs=-1)
    multi_class_clf.fit(X_train, y_train)
    # each review has proba for 10 classes
    scores = multi_class_clf.predict_proba(X_test)
    return scores

def get_class_label_name(scores,idx):
    ''' input a review index, and get the predicted label 
    (the one with highest probability) for this review'''
    label_encoded = np.argmax(scores[idx])
    return [key for key in labels_index if labels_index[key] ==label_encoded ].pop()

def add_pred_to_df(scores, df):
    '''add predicted labels to original df'''
    predicted_labels = []
    for i in range(len(scores)):
        label_pred = get_class_label_name(scores,i)
        predicted_labels.append(label_pred)
    # add predicted labels to original test df
    df['pred_label'] = predicted_labels
    return df

def get_confusion_matrix(y_test,y_pred):
    '''get confusion matrix (tp,tn,fp,fn) for each class'''
    cm = ConfusionMatrix(y_test, y_pred)
    cm.print_stats()

# %%
## Data Preprocess
# load data and split data
data_p = PrepareData()
data = data_p.load_data('../res/labeled_data_with_without_tk.csv')
train, test = data_p.split_data()

# X_train, X_test is the vectorized tokens that represent each review
X_train, y_train, X_test, y_test = data_p.preprocess_data()

# get label dictionary
labels_index = data_p.get_labels_index()
print(labels_index)

# convert encoded labels into one-hot encoding, using keras to_categorical functions
y_train_transformed = to_categorical(y_train, dtype='float32')
y_test_transformed = to_categorical(y_test, dtype='float32')
# Out:
# training data has 1038 examples
# test data has 512 examples
# {'计划': 7, '机上': 5, '中转': 0, '售后': 3, '预订': 9, '设计': 8, '出发': 1, '性能': 4, '行程': 6, '到达': 2}

# %%
## logistic regression
model = LogisticRegression()
# get predicted proba for each review of the 10 classes
scores = predict_label(model,X_train,y_train_transformed)
# add prediction results to original df
test_with_predictions = add_pred_to_df(scores, test)

y_test = test.label.values
y_pred = test.pred_label.values
# get confusion matrix
get_confusion_matrix(y_test,y_pred)

# check prediction results
test_with_predictions.head()
# Out:
# Confusion Matrix:
#
# Predicted  中转   出发  到达  售后  性能   机上  行程  计划  设计  预订  __all__
# Actual
# 中转         24   19   1   1   0    8   0   0   0   1       54
# 出发          7   70  12   7   1   14   0   0   0   1      112
# 到达          2    8  22   0   0   15   0   0   0   0       47
# 售后          0   14   0  23   0    7   1   0   0   3       48
# 性能          0    7   0   4  14   10   2   0   0  18       55
# 机上          1   17   2   0   0   71   0   0   0   2       93
# 行程          0    7   0   2   0    1   5   0   0   3       18
# 计划          0    0   0   0   1    2   0   1   0   3        7
# 设计          0    2   0   0   4    1   0   0   1   4       12
# 预订          0    5   1   3   4    6   0   0   0  47       66
# __all__    34  149  38  40  24  135   8   1   1  82      512
#
#
# Overall Statistics:
#
# Accuracy: 0.54296875
# 95% CI: (0.49870046846820293, 0.5867382423122843)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.1324495084024356e-32
# Kappa: 0.4565643370346179
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                       中转        出发         到达  \
# Population                                   512       512        512
# P: Condition positive                         54       112         47
# N: Condition negative                        458       400        465
# Test outcome positive                         34       149         38
# Test outcome negative                        478       363        474
# TP: True Positive                             24        70         22
# TN: True Negative                            448       321        449
# FP: False Positive                            10        79         16
# FN: False Negative                            30        42         25
# TPR: (Sensitivity, hit rate, recall)    0.444444     0.625   0.468085
# TNR=SPC: (Specificity)                  0.978166    0.8025   0.965591
# PPV: Pos Pred Value (Precision)         0.705882  0.469799   0.578947
# NPV: Neg Pred Value                     0.937238  0.884298   0.947257
# FPR: False-out                         0.0218341    0.1975  0.0344086
# FDR: False Discovery Rate               0.294118  0.530201   0.421053
# FNR: Miss Rate                          0.555556     0.375   0.531915
# ACC: Accuracy                           0.921875  0.763672   0.919922
# F1 score                                0.545455  0.536398   0.517647
# MCC: Matthews correlation coefficient   0.521334  0.389071   0.477706
# Informedness                             0.42261    0.4275   0.433677
# Markedness                              0.643121  0.354096   0.526205
# Prevalence                              0.105469   0.21875  0.0917969
# LR+: Positive likelihood ratio           20.3556   3.16456    13.6037
# LR-: Negative likelihood ratio          0.567956   0.46729    0.55087
# DOR: Diagnostic odds ratio                 35.84   6.77215     24.695
# FOR: False omission rate               0.0627615  0.115702  0.0527426
#
# Classes                                       售后         性能         机上  \
# Population                                   512        512        512
# P: Condition positive                         48         55         93
# N: Condition negative                        464        457        419
# Test outcome positive                         40         24        135
# Test outcome negative                        472        488        377
# TP: True Positive                             23         14         71
# TN: True Negative                            447        447        355
# FP: False Positive                            17         10         64
# FN: False Negative                            25         41         22
# TPR: (Sensitivity, hit rate, recall)    0.479167   0.254545   0.763441
# TNR=SPC: (Specificity)                  0.963362   0.978118   0.847255
# PPV: Pos Pred Value (Precision)            0.575   0.583333   0.525926
# NPV: Neg Pred Value                     0.947034   0.915984   0.941645
# FPR: False-out                         0.0366379  0.0218818   0.152745
# FDR: False Discovery Rate                  0.425   0.416667   0.474074
# FNR: Miss Rate                          0.520833   0.745455   0.236559
# ACC: Accuracy                           0.917969   0.900391   0.832031
# F1 score                                0.522727    0.35443   0.622807
# MCC: Matthews correlation coefficient    0.48064   0.340841   0.534363
# Informedness                            0.442529   0.232664   0.610696
# Markedness                              0.522034   0.499317    0.46757
# Prevalence                               0.09375   0.107422   0.181641
# LR+: Positive likelihood ratio           13.0784    11.6327    4.99815
# LR-: Negative likelihood ratio          0.540641   0.762131   0.279206
# DOR: Diagnostic odds ratio               24.1906    15.2634    17.9013
# FOR: False omission rate               0.0529661  0.0840164  0.0583554
#
# Classes                                        行程         计划         设计  \
# Population                                    512        512        512
# P: Condition positive                          18          7         12
# N: Condition negative                         494        505        500
# Test outcome positive                           8          1          1
# Test outcome negative                         504        511        511
# TP: True Positive                               5          1          1
# TN: True Negative                             491        505        500
# FP: False Positive                              3          0          0
# FN: False Negative                             13          6         11
# TPR: (Sensitivity, hit rate, recall)     0.277778   0.142857  0.0833333
# TNR=SPC: (Specificity)                   0.993927          1          1
# PPV: Pos Pred Value (Precision)             0.625          1          1
# NPV: Neg Pred Value                      0.974206   0.988258   0.978474
# FPR: False-out                         0.00607287          0          0
# FDR: False Discovery Rate                   0.375          0          0
# FNR: Miss Rate                           0.722222   0.857143   0.916667
# ACC: Accuracy                             0.96875   0.988281   0.978516
# F1 score                                 0.384615       0.25   0.153846
# MCC: Matthews correlation coefficient    0.403494   0.375739   0.285551
# Informedness                             0.271705   0.142857  0.0833333
# Markedness                               0.599206   0.988258   0.978474
# Prevalence                              0.0351562  0.0136719  0.0234375
# LR+: Positive likelihood ratio            45.7407        inf        inf
# LR-: Negative likelihood ratio           0.726635   0.857143   0.916667
# DOR: Diagnostic odds ratio                62.9487        inf        inf
# FOR: False omission rate                0.0257937  0.0117417  0.0215264
#
# Classes                                       预订
# Population                                   512
# P: Condition positive                         66
# N: Condition negative                        446
# Test outcome positive                         82
# Test outcome negative                        430
# TP: True Positive                             47
# TN: True Negative                            411
# FP: False Positive                            35
# FN: False Negative                            19
# TPR: (Sensitivity, hit rate, recall)    0.712121
# TNR=SPC: (Specificity)                  0.921525
# PPV: Pos Pred Value (Precision)         0.573171
# NPV: Neg Pred Value                     0.955814
# FPR: False-out                         0.0784753
# FDR: False Discovery Rate               0.426829
# FNR: Miss Rate                          0.287879
# ACC: Accuracy                           0.894531
# F1 score                                0.635135
# MCC: Matthews correlation coefficient   0.578955
# Informedness                            0.633646
# Markedness                              0.528985
# Prevalence                              0.128906
# LR+: Positive likelihood ratio           9.07446
# LR-: Negative likelihood ratio          0.312394
# DOR: Diagnostic odds ratio               29.0481
# FOR: False omission rate                0.044186
#                                                  review  \
# 1520                  行李箱丢了！在荷兰机场语言不通，你们航空公司也没个人来管事，解释！
# 1442  昨晚（11月11日）我搭乘cz8278次18:25长沙飞海口的航班，飞机下降临近海口时，我突...
# 351   延误能不能早点通知，我就好修改航班，下午16点到机场，延误就早点通知，我就能修改18点的航班...
# 352                                                严重晚点
# 578   我在网上补登里程、只能䃼登上9月24日南京-广州、国际段䃼登不上、麻烦处理一下。 zhu n...
#
#                                           review_tokens label  label_encoded  \
# 1520                        行李箱 丢 荷兰 机场 语言不通 航空公司 管事 解释    到达              2
# 1442  昨晚 月 日 搭乘 次 长沙 飞 海口 航班 飞机 下降 临近 海口 时 突发 眩晕 症 四...    到达              2
# 351   延误 早点 通知 修改 航班 下午 点到 机场 延误 早点 通知 修改 点 航班 延误 晚上...    中转              0
# 352                                                  晚点    中转              0
# 578   网上 补登 里程 只能 登上 月 日 南京 广州 国际 段 登不上 麻烦 朱宁生 月 日 票...    售后              3
#
#      pred_label
# 1520         出发
# 1442         机上
# 351          出发
# 352          出发
# 578          售后

# %%
## MultinomialNB  
model = MultinomialNB()
# get predicted proba for each review of the 10 classes
scores = predict_label(model,X_train,y_train_transformed)
# add prediction results to original df
test_with_predictions = add_pred_to_df(scores, test)

y_test = test.label.values
y_pred = test.pred_label.values
# get confusion matrix
get_confusion_matrix(y_test,y_pred)

# check prediction results
test_with_predictions.head()
# Out:
# Confusion Matrix:
#
# Predicted  中转   出发  到达  售后  性能  机上  行程  计划  设计   预订  __all__
# Actual
# 中转          2   41   1   0   0   8   0   0   0    2       54
# 出发          2   93   6   4   0   5   0   0   0    2      112
# 到达          0   28   8   0   0  11   0   0   0    0       47
# 售后          0   23   0  18   0   0   0   0   0    7       48
# 性能          0   13   0   2  12   3   1   0   0   24       55
# 机上          1   26   1   0   0  63   0   0   0    2       93
# 行程          0   12   0   1   0   0   1   0   0    4       18
# 计划          0    2   0   0   1   0   0   0   0    4        7
# 设计          0    1   0   0   4   1   0   0   1    5       12
# 预订          0   13   0   1   1   1   0   0   0   50       66
# __all__     5  252  16  26  18  92   2   0   1  100      512
#
#
# Overall Statistics:
#
# Accuracy: 0.484375
# 95% CI: (0.4403084038830422, 0.5286229575124253)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.6545180934422876
# Kappa: 0.37264221001039655
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        中转         出发         到达  \
# Population                                    512        512        512
# P: Condition positive                          54        112         47
# N: Condition negative                         458        400        465
# Test outcome positive                           5        252         16
# Test outcome negative                         507        260        496
# TP: True Positive                               2         93          8
# TN: True Negative                             455        241        457
# FP: False Positive                              3        159          8
# FN: False Negative                             52         19         39
# TPR: (Sensitivity, hit rate, recall)     0.037037   0.830357   0.170213
# TNR=SPC: (Specificity)                    0.99345     0.6025   0.982796
# PPV: Pos Pred Value (Precision)               0.4   0.369048        0.5
# NPV: Neg Pred Value                      0.897436   0.926923   0.921371
# FPR: False-out                         0.00655022     0.3975  0.0172043
# FDR: False Discovery Rate                     0.6   0.630952        0.5
# FNR: Miss Rate                           0.962963   0.169643   0.829787
# ACC: Accuracy                            0.892578   0.652344   0.908203
# F1 score                                0.0677966   0.510989   0.253968
# MCC: Matthews correlation coefficient   0.0952254   0.357929   0.253916
# Informedness                            0.0304868   0.432857   0.153008
# Markedness                               0.297436   0.295971   0.421371
# Prevalence                               0.105469    0.21875  0.0917969
# LR+: Positive likelihood ratio            5.65432    2.08895    9.89362
# LR-: Negative likelihood ratio           0.969312   0.281565   0.844313
# DOR: Diagnostic odds ratio                5.83333    7.41907    11.7179
# FOR: False omission rate                 0.102564  0.0730769   0.078629
#
# Classes                                       售后         性能         机上  \
# Population                                   512        512        512
# P: Condition positive                         48         55         93
# N: Condition negative                        464        457        419
# Test outcome positive                         26         18         92
# Test outcome negative                        486        494        420
# TP: True Positive                             18         12         63
# TN: True Negative                            456        451        390
# FP: False Positive                             8          6         29
# FN: False Negative                            30         43         30
# TPR: (Sensitivity, hit rate, recall)       0.375   0.218182   0.677419
# TNR=SPC: (Specificity)                  0.982759   0.986871   0.930788
# PPV: Pos Pred Value (Precision)         0.692308   0.666667   0.684783
# NPV: Neg Pred Value                     0.938272   0.912955   0.928571
# FPR: False-out                         0.0172414  0.0131291  0.0692124
# FDR: False Discovery Rate               0.307692   0.333333   0.315217
# FNR: Miss Rate                             0.625   0.781818   0.322581
# ACC: Accuracy                           0.925781   0.904297   0.884766
# F1 score                                0.486486   0.328767   0.681081
# MCC: Matthews correlation coefficient   0.474969   0.344751   0.610775
# Informedness                            0.357759   0.205053   0.608207
# Markedness                              0.630579   0.579622   0.613354
# Prevalence                               0.09375   0.107422   0.181641
# LR+: Positive likelihood ratio             21.75    16.6182    9.78754
# LR-: Negative likelihood ratio          0.635965   0.792219   0.346567
# DOR: Diagnostic odds ratio                  34.2    20.9767    28.2414
# FOR: False omission rate               0.0617284  0.0870445  0.0714286
#
# Classes                                        行程         计划         设计  \
# Population                                    512        512        512
# P: Condition positive                          18          7         12
# N: Condition negative                         494        505        500
# Test outcome positive                           2          0          1
# Test outcome negative                         510        512        511
# TP: True Positive                               1          0          1
# TN: True Negative                             493        505        500
# FP: False Positive                              1          0          0
# FN: False Negative                             17          7         11
# TPR: (Sensitivity, hit rate, recall)    0.0555556          0  0.0833333
# TNR=SPC: (Specificity)                   0.997976          1          1
# PPV: Pos Pred Value (Precision)               0.5        NaN          1
# NPV: Neg Pred Value                      0.966667   0.986328   0.978474
# FPR: False-out                         0.00202429          0          0
# FDR: False Discovery Rate                     0.5        NaN          0
# FNR: Miss Rate                           0.944444          1   0.916667
# ACC: Accuracy                            0.964844   0.986328   0.978516
# F1 score                                      0.1          0   0.153846
# MCC: Matthews correlation coefficient    0.158055        NaN   0.285551
# Informedness                            0.0535313          0  0.0833333
# Markedness                               0.466667        NaN   0.978474
# Prevalence                              0.0351562  0.0136719  0.0234375
# LR+: Positive likelihood ratio            27.4444        NaN        inf
# LR-: Negative likelihood ratio            0.94636          1   0.916667
# DOR: Diagnostic odds ratio                     29        NaN        inf
# FOR: False omission rate                0.0333333  0.0136719  0.0215264
#
# Classes                                      预订
# Population                                  512
# P: Condition positive                        66
# N: Condition negative                       446
# Test outcome positive                       100
# Test outcome negative                       412
# TP: True Positive                            50
# TN: True Negative                           396
# FP: False Positive                           50
# FN: False Negative                           16
# TPR: (Sensitivity, hit rate, recall)   0.757576
# TNR=SPC: (Specificity)                 0.887892
# PPV: Pos Pred Value (Precision)             0.5
# NPV: Neg Pred Value                    0.961165
# FPR: False-out                         0.112108
# FDR: False Discovery Rate                   0.5
# FNR: Miss Rate                         0.242424
# ACC: Accuracy                          0.871094
# F1 score                                0.60241
# MCC: Matthews correlation coefficient  0.545589
# Informedness                           0.645468
# Markedness                             0.461165
# Prevalence                             0.128906
# LR+: Positive likelihood ratio          6.75758
# LR-: Negative likelihood ratio         0.273033
# DOR: Diagnostic odds ratio                24.75
# FOR: False omission rate               0.038835
#                                                  review  \
# 1520                  行李箱丢了！在荷兰机场语言不通，你们航空公司也没个人来管事，解释！
# 1442  昨晚（11月11日）我搭乘cz8278次18:25长沙飞海口的航班，飞机下降临近海口时，我突...
# 351   延误能不能早点通知，我就好修改航班，下午16点到机场，延误就早点通知，我就能修改18点的航班...
# 352                                                严重晚点
# 578   我在网上补登里程、只能䃼登上9月24日南京-广州、国际段䃼登不上、麻烦处理一下。 zhu n...
#
#                                           review_tokens label  label_encoded  \
# 1520                        行李箱 丢 荷兰 机场 语言不通 航空公司 管事 解释    到达              2
# 1442  昨晚 月 日 搭乘 次 长沙 飞 海口 航班 飞机 下降 临近 海口 时 突发 眩晕 症 四...    到达              2
# 351   延误 早点 通知 修改 航班 下午 点到 机场 延误 早点 通知 修改 点 航班 延误 晚上...    中转              0
# 352                                                  晚点    中转              0
# 578   网上 补登 里程 只能 登上 月 日 南京 广州 国际 段 登不上 麻烦 朱宁生 月 日 票...    售后              3
#
#      pred_label
# 1520         出发
# 1442         机上
# 351          出发
# 352          出发
# 578          出发
