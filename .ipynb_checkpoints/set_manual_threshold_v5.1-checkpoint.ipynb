# %% [markdown]
# README:
# - updated: reorganize codes based on v5
# - use vectorized method for multi-class classification

# %%
import pandas as pd
import os
os.chdir('/Users/liyuan/desktop/CSAir/codes')
import numpy as np
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

from sklearn.naive_bayes import MultinomialNB  
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from modeling_main import ReviewClassify
from tokenization import Tokenization
from help import get_tokenized_sent, get_stopwords

# updated: 04/17/2019
from prepare_data import PrepareData
from modeling import Modeling

import keras
from keras.utils import to_categorical
from sklearn.multiclass import OneVsRestClassifier
import seaborn as sns
from sklearn.metrics import confusion_matrix
from pandas_ml import ConfusionMatrix
# Out:
# Using TensorFlow backend.

# %%
def predict_label(model,X_train,y_train):
    ''' predict label for each review, by picking the class with highest probability'''
    multi_class_clf = OneVsRestClassifier(model, n_jobs=-1)
    multi_class_clf.fit(X_train, y_train)
    # each review has proba for 10 classes
    scores = multi_class_clf.predict_proba(X_test)
    return scores

def get_class_label_name(scores,idx):
    ''' input a review index, and get the predicted label 
    (the one with highest probability) for this review'''
    label_encoded = np.argmax(scores[idx])
    return [key for key in labels_index if labels_index[key] ==label_encoded ].pop()

def add_pred_to_df(scores, df):
    '''add predicted labels to original df'''
    predicted_labels = []
    for i in range(len(scores)):
        label_pred = get_class_label_name(scores,i)
        predicted_labels.append(label_pred)
    # add predicted labels to original test df
    df['pred_label'] = predicted_labels
    return df

def get_confusion_matrix(y_test,y_pred):
    '''get confusion matrix (tp,tn,fp,fn) for each class'''
    cm = ConfusionMatrix(y_test, y_pred)
    cm.print_stats()

# %%
## Data Preprocess
# load data and split data
data_p = PrepareData()
data = data_p.load_data('../res/labeled_data_with_without_tk.csv')
train, test = data_p.split_data()

# X_train, X_test is the vectorized tokens that represent each review
X_train, y_train, X_test, y_test = data_p.preprocess_data()

# get label dictionary
labels_index = data_p.get_labels_index()
print(labels_index)

# convert encoded labels into one-hot encoding, using keras to_categorical functions
y_train_transformed = to_categorical(y_train, dtype='float32')
y_test_transformed = to_categorical(y_test, dtype='float32')
# Out:
# training data has 1038 examples
# test data has 512 examples
# {'计划': 7, '机上': 5, '中转': 0, '售后': 3, '预订': 9, '设计': 8, '出发': 1, '性能': 4, '行程': 6, '到达': 2}

# %%
# define modeling method
model = LogisticRegression()
# get predicted proba for each review of the 10 classes
scores = predict_label(model,X_train,y_train_transformed)
# add prediction results to original df
test_with_predictions = add_pred_to_df(scores, test)

y_test = test.label.values
y_pred = test.pred_label.values
# get confusion matrix
get_confusion_matrix(y_test,y_pred)
# Out:
# Confusion Matrix:
#
# Predicted  中转   出发  到达  售后  性能   机上  行程  计划  设计  预订  __all__
# Actual
# 中转         24   19   1   1   0    8   0   0   0   1       54
# 出发          7   68  12   7   1   16   0   0   0   1      112
# 到达          2    8  21   0   0   16   0   0   0   0       47
# 售后          0   13   0  24   1    5   1   0   0   4       48
# 性能          0    8   0   4  15    9   2   0   0  17       55
# 机上          1   16   2   0   0   72   0   0   0   2       93
# 行程          0    6   0   2   0    2   5   0   0   3       18
# 计划          0    0   0   0   1    2   0   0   0   4        7
# 设计          0    1   0   0   4    2   0   0   1   4       12
# 预订          0    6   1   3   3    5   0   0   0  48       66
# __all__    34  145  37  41  25  137   8   0   1  84      512
#
#
# Overall Statistics:
#
# Accuracy: 0.54296875
# 95% CI: (0.49870046846820293, 0.5867382423122843)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 7.479843526496029e-35
# Kappa: 0.45676392572944297
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                       中转        出发         到达  \
# Population                                   512       512        512
# P: Condition positive                         54       112         47
# N: Condition negative                        458       400        465
# Test outcome positive                         34       145         37
# Test outcome negative                        478       367        475
# TP: True Positive                             24        68         21
# TN: True Negative                            448       323        449
# FP: False Positive                            10        77         16
# FN: False Negative                            30        44         26
# TPR: (Sensitivity, hit rate, recall)    0.444444  0.607143   0.446809
# TNR=SPC: (Specificity)                  0.978166    0.8075   0.965591
# PPV: Pos Pred Value (Precision)         0.705882  0.468966   0.567568
# NPV: Neg Pred Value                     0.937238  0.880109   0.945263
# FPR: False-out                         0.0218341    0.1925  0.0344086
# FDR: False Discovery Rate               0.294118  0.531034   0.432432
# FNR: Miss Rate                          0.555556  0.392857   0.553191
# ACC: Accuracy                           0.921875  0.763672   0.917969
# F1 score                                0.545455  0.529183        0.5
# MCC: Matthews correlation coefficient   0.521334  0.380449   0.459882
# Informedness                             0.42261  0.414643     0.4124
# Markedness                              0.643121  0.349075   0.512831
# Prevalence                              0.105469   0.21875  0.0917969
# LR+: Positive likelihood ratio           20.3556   3.15399    12.9854
# LR-: Negative likelihood ratio          0.567956   0.48651   0.572904
# DOR: Diagnostic odds ratio                 35.84   6.48288    22.6659
# FOR: False omission rate               0.0627615  0.119891  0.0547368
#
# Classes                                       售后         性能        机上  \
# Population                                   512        512       512
# P: Condition positive                         48         55        93
# N: Condition negative                        464        457       419
# Test outcome positive                         41         25       137
# Test outcome negative                        471        487       375
# TP: True Positive                             24         15        72
# TN: True Negative                            447        447       354
# FP: False Positive                            17         10        65
# FN: False Negative                            24         40        21
# TPR: (Sensitivity, hit rate, recall)         0.5   0.272727  0.774194
# TNR=SPC: (Specificity)                  0.963362   0.978118  0.844869
# PPV: Pos Pred Value (Precision)         0.585366        0.6  0.525547
# NPV: Neg Pred Value                     0.949045   0.917864     0.944
# FPR: False-out                         0.0366379  0.0218818  0.155131
# FDR: False Discovery Rate               0.414634        0.4  0.474453
# FNR: Miss Rate                               0.5   0.727273  0.225806
# ACC: Accuracy                           0.919922   0.902344  0.832031
# F1 score                                0.539326      0.375  0.626087
# MCC: Matthews correlation coefficient    0.49762   0.360422  0.539147
# Informedness                            0.463362   0.250845  0.619062
# Markedness                               0.53441   0.517864  0.469547
# Prevalence                               0.09375   0.107422  0.181641
# LR+: Positive likelihood ratio           13.6471    12.4636   4.99057
# LR-: Negative likelihood ratio          0.519016   0.743543  0.267268
# DOR: Diagnostic odds ratio               26.2941    16.7625   18.6725
# FOR: False omission rate               0.0509554  0.0821355     0.056
#
# Classes                                        行程         计划         设计  \
# Population                                    512        512        512
# P: Condition positive                          18          7         12
# N: Condition negative                         494        505        500
# Test outcome positive                           8          0          1
# Test outcome negative                         504        512        511
# TP: True Positive                               5          0          1
# TN: True Negative                             491        505        500
# FP: False Positive                              3          0          0
# FN: False Negative                             13          7         11
# TPR: (Sensitivity, hit rate, recall)     0.277778          0  0.0833333
# TNR=SPC: (Specificity)                   0.993927          1          1
# PPV: Pos Pred Value (Precision)             0.625        NaN          1
# NPV: Neg Pred Value                      0.974206   0.986328   0.978474
# FPR: False-out                         0.00607287          0          0
# FDR: False Discovery Rate                   0.375        NaN          0
# FNR: Miss Rate                           0.722222          1   0.916667
# ACC: Accuracy                             0.96875   0.986328   0.978516
# F1 score                                 0.384615          0   0.153846
# MCC: Matthews correlation coefficient    0.403494        NaN   0.285551
# Informedness                             0.271705          0  0.0833333
# Markedness                               0.599206        NaN   0.978474
# Prevalence                              0.0351562  0.0136719  0.0234375
# LR+: Positive likelihood ratio            45.7407        NaN        inf
# LR-: Negative likelihood ratio           0.726635          1   0.916667
# DOR: Diagnostic odds ratio                62.9487        NaN        inf
# FOR: False omission rate                0.0257937  0.0136719  0.0215264
#
# Classes                                       预订
# Population                                   512
# P: Condition positive                         66
# N: Condition negative                        446
# Test outcome positive                         84
# Test outcome negative                        428
# TP: True Positive                             48
# TN: True Negative                            410
# FP: False Positive                            36
# FN: False Negative                            18
# TPR: (Sensitivity, hit rate, recall)    0.727273
# TNR=SPC: (Specificity)                  0.919283
# PPV: Pos Pred Value (Precision)         0.571429
# NPV: Neg Pred Value                     0.957944
# FPR: False-out                         0.0807175
# FDR: False Discovery Rate               0.428571
# FNR: Miss Rate                          0.272727
# ACC: Accuracy                           0.894531
# F1 score                                    0.64
# MCC: Matthews correlation coefficient   0.585037
# Informedness                            0.646555
# Markedness                              0.529372
# Prevalence                              0.128906
# LR+: Positive likelihood ratio            9.0101
# LR-: Negative likelihood ratio          0.296674
# DOR: Diagnostic odds ratio               30.3704
# FOR: False omission rate               0.0420561

# %%
# check prediction results
test_with_predictions.head()
# Out:
#                                                  review  \
# 1520                  行李箱丢了！在荷兰机场语言不通，你们航空公司也没个人来管事，解释！
# 1442  昨晚（11月11日）我搭乘cz8278次18:25长沙飞海口的航班，飞机下降临近海口时，我突...
# 351   延误能不能早点通知，我就好修改航班，下午16点到机场，延误就早点通知，我就能修改18点的航班...
# 352                                                严重晚点
# 578   我在网上补登里程、只能䃼登上9月24日南京-广州、国际段䃼登不上、麻烦处理一下。 zhu n...
#
#                                           review_tokens label  label_encoded  \
# 1520                        行李箱 丢 荷兰 机场 语言不通 航空公司 管事 解释    到达              2
# 1442  昨晚  月  日 搭乘 cz 次   长沙 飞 海口 航班 飞机 下降 临近 海口 时 突发...    到达              2
# 351   延误 早点 通知 修改 航班 下午  点到 机场 延误 早点 通知 修改  点 航班 延误 ...    中转              0
# 352                                                  晚点    中转              0
# 578   网上 补登 里程 只能 䃼 登上 月  日 南京 广州 国际 段 䃼 登不上 麻烦   zh...    售后              3
#
#      pred_label
# 1520         出发
# 1442         机上
# 351          出发
# 352          出发
# 578          售后
